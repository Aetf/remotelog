# %%
import analysis as ana
import importlib as ilb
# %matplotlib inline

# %% [markdown]
# # 2016-6-01
#
# - 1: 32+32 cores, 2+40+2, 13 FPS
# - 2: 32+32 cores, 2+50+2, 13 FPS
# - 3: 32+32 cores, 2+60+2, 13 FPS [FG]
# - 4: 32+32 cores, 2+80+2, 13 FPS
# - 5: 32+32 cores, 2+100+2, 13 FPS

# %%
mul = ana.cross_res(*(['2016-6-01/{}'.format(i) for i in range(1,6)]))
# Out:
# Collect log from ['archive/2016-6-01/1/clarity25/dnn_classification-1-1464790771-worker-6721.log']
# Collect cpu log from archive/2016-6-01/1/clarity25/log.cpu
# Collect log from ['archive/2016-6-01/1/clarity26/dnn_classification-1-1464790771-worker-6721.log']
# Collect cpu log from archive/2016-6-01/1/clarity26/log.cpu
# Auto fixed cross stage timming issues for 78 log entries
# Dropped 0 frames
# Collect log from ['archive/2016-6-01/2/clarity25/dnn_classification-1-1464791153-worker-6721.log']
# Collect cpu log from archive/2016-6-01/2/clarity25/log.cpu
# Collect log from ['archive/2016-6-01/2/clarity26/dnn_classification-1-1464791153-worker-6721.log']
# Collect cpu log from archive/2016-6-01/2/clarity26/log.cpu
# WARNING: seq 576: consecutive entering on stage spout and scale with stamp difference 41
# Auto fixed cross stage timming issues for 145 log entries
# Dropped 0 frames
# Collect log from ['archive/2016-6-01/3/clarity25/dnn_classification-1-1464791540-worker-6721.log']
# Collect cpu log from archive/2016-6-01/3/clarity25/log.cpu
# Collect log from ['archive/2016-6-01/3/clarity26/dnn_classification-1-1464791540-worker-6721.log']
# Collect cpu log from archive/2016-6-01/3/clarity26/log.cpu
# WARNING: seq 1867: consecutive leaving on stage drawer and fat_features with stamp difference 34
# WARNING: seq 946: consecutive entering on stage drawer and streamer with stamp difference 134
# Auto fixed cross stage timming issues for 118 log entries
# Dropped 0 frames
# Collect log from ['archive/2016-6-01/4/clarity25/dnn_classification-1-1464791929-worker-6721.log']
# Collect cpu log from archive/2016-6-01/4/clarity25/log.cpu
# Collect log from ['archive/2016-6-01/4/clarity26/dnn_classification-1-1464791929-worker-6721.log']
# Collect cpu log from archive/2016-6-01/4/clarity26/log.cpu
# WARNING: seq 2969: consecutive entering on stage spout and scale with stamp difference 41
# WARNING: seq 2752: consecutive entering on stage spout and scale with stamp difference 36
# Auto fixed cross stage timming issues for 117 log entries
# Dropped 2 frames
# Collect log from ['archive/2016-6-01/5/clarity25/dnn_classification-1-1464809211-worker-6721.log']
# Collect cpu log from archive/2016-6-01/5/clarity25/log.cpu
# Collect log from ['archive/2016-6-01/5/clarity26/dnn_classification-1-1464809211-worker-6721.log']
# Collect cpu log from archive/2016-6-01/5/clarity26/log.cpu
# WARNING: malformated cpu log: "cpu19	-5.94059405941
# "
# Auto fixed cross stage timming issues for 154 log entries
# Dropped 0 frames

# %%
mul.fps()
mul.latency()
# Out:
# /home/aetf/desktop/remotelog/analysis.py:844: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   df = df.sort('Threads for fat_features')
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc27e1b4358>,
#           total  Threads for fat_features
#  0  3249.350621                        40
#  1  2925.263002                        50
#  2  2628.466935                        60
#  3  2817.277222                        80
#  4  2732.277598                       100)

# %% [markdown]
# - 6: 32+32 cores, 2+40+2, 14 FPS
# - 7: 32+32 cores, 2+50+2, 14 FPS
# - 8: 32+32 cores, 2+60+2, 14 FPS
# - 9: 32+32 cores, 2+80+2, 14 FPS [FG]
# - 10: 32+32 cores, 2+100+2, 14 FPS
#
# #### The following are invalid because fps does not actually reach specified value
#
# - 11: 32+32 cores, 2+40+2, 15 FPS
# - 12: 32+32 cores, 2+50+2, 15 FPS
# - 13: 32+32 cores, 2+60+2, 15 FPS
# - 14: 32+32 cores, 2+80+2, 15 FPS
# - 15: 32+32 cores, 2+100+2, 15 FPS
#
# - 16: 32+32 cores, 2+40+2, 16 FPS
# - 17: 32+32 cores, 2+50+2, 16 FPS
# - 18: 32+32 cores, 2+60+2, 16 FPS
# - 19: 32+32 cores, 2+80+2, 16 FPS
# - 20: 32+32 cores, 2+100+2, 16 FPS
#
# - 21: 32+32 cores, 2+40+2, 18 FPS
# - 22: 32+32 cores, 2+50+2, 18 FPS
# - 23: 32+32 cores, 2+60+2, 18 FPS
# - 24: 32+32 cores, 2+80+2, 18 FPS
# - 25: 32+32 cores, 2+100+2, 18 FPS
#
# - 26: 32+32 cores, 2+40+2, 20 FPS
# - 27: 32+32 cores, 2+50+2, 20 FPS
# - 28: 32+32 cores, 2+60+2, 20 FPS
# - 29: 32+32 cores, 2+80+2, 20 FPS
# - 30: 32+32 cores, 2+100+2, 20 FPS

# %% [markdown]
# # 2016-6-02
#
# - 1: 32+32 cores, 2+40+2, 17 FPS
# - 2: 32+32 cores, 2+100+2, 24 FPS
# - 3: 32+32 cores, 2+100+2, 34 FPS
#
#
# - 4: 32+32 cores, 2+40+2, 15 FPS
# - 5: 32+32 cores, 2+50+2, 15 FPS
# - 6: 32+32 cores, 2+60+2, 15 FPS
# - 7: 32+32 cores, 2+80+2, 15 FPS
# - 8: 32+32 cores, 2+100+2, 15 FPS
#
# - 9: 32+32 cores, 2+40+2, 16 FPS
# - 10: 32+32 cores, 2+50+2, 16 FPS
# - 11: 32+32 cores, 2+60+2, 16 FPS
# - 12: 32+32 cores, 2+80+2, 16 FPS
# - 13: 32+32 cores, 2+100+2, 16 FPS
#
# - 14: 32+32 cores, 2+40+2, 18 FPS
# - 15: 32+32 cores, 2+50+2, 18 FPS
# - 16: 32+32 cores, 2+60+2, 18 FPS
# - 17: 32+32 cores, 2+80+2, 18 FPS
# - 18: 32+32 cores, 2+100+2, 18 FPS
#
# - 19: 32+32 cores, 2+40+2, 20 FPS
# - 20: 32+32 cores, 2+50+2, 20 FPS
# - 21: 32+32 cores, 2+60+2, 20 FPS
# - 22: 32+32 cores, 2+80+2, 20 FPS
# - 23: 32+32 cores, 2+100+2, 20 FPS

# %% [markdown]
# # 2016-6-03
#
# - 1: 32+32 cores, 2+40+2, 18 FPS with start-delay
# - 2: 8 cores, 1+5+1, 1 FPS
# - 3: 8 cores, 1+5+1, 2 FPS
# - 4: 16 cores, 1+27+1, 1 FPS
# - 5: 16 cores, 1+27+1, 2 FPS
# - 6: 32 cores, 1+27+1, 1 FPS
# - 7: 32 cores, 1+27+1, 2 FPS
# - 8: 32+32 cores, 1+50+1, 1 FPS
# - 9: 32+32 cores, 1+50+1, 2 FPS
# - 10: 32+32 cores, 2+50+2, 1 FPS
# - 11: 32+32 cores, 2+50+2, 2 FPS

# %% [markdown]
# ### Service time with low workload

# %%
core8 = ana.cross_res('2016-6-03/2', '2016-6-03/3')
core8.latency(x=('FPS', lambda exp: int(exp.params['fps'])))
# Out:
# Collect log from ['archive/2016-6-03/2/clarity26/dnn_classification-1-1464989391-worker-6721.log']
# Collect cpu log from archive/2016-6-03/2/clarity26/log.cpu
# Auto fixed cross stage timming issues for 4 log entries
# Dropped 0 frames
# Collect log from ['archive/2016-6-03/3/clarity26/dnn_classification-1-1464989796-worker-6721.log']
# Collect cpu log from archive/2016-6-03/3/clarity26/log.cpu
# Auto fixed cross stage timming issues for 12 log entries
# Dropped 0 frames
# /home/aetf/desktop/remotelog/analysis.py:848: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f270c23ee80>,          total  FPS
#  0  1768.593960    1
#  1  1887.699664    2)

# %%
core16 =

# %% [markdown]
# ### Max FPS with latency limit at 2.5s

# %% [markdown]
# ### Check if frames are only processed on the same machine when possible
# Conclusion: no, there are frames using scale on clarity__25__ but sent to fat_features on clatiry__26__ and vice versa

# %%
ilb.reload(ana)
res = ana.exp_res('2016-6-02/4')
res.show_log(2720)
# Out:
# Collect log from ['archive/2016-6-02/4/clarity25/dnn_classification-1-1464893993-worker-6721.log']
# Collect cpu log from archive/2016-6-02/4/clarity25/log.cpu
# Collect log from ['archive/2016-6-02/4/clarity26/dnn_classification-1-1464893993-worker-6721.log']
# Collect cpu log from archive/2016-6-02/4/clarity26/log.cpu
# WARNING: seq 72: consecutive entering on stage spout and scale with stamp difference 83
# WARNING: seq 3963: consecutive entering on stage drawer and streamer with stamp difference 47
# WARNING: seq 2721: consecutive entering on stage spout and scale with stamp difference 31
# Auto fixed cross stage timming issues for 110 log entries
# Dropped 0 frames
# Machine: clarity26 Seq: 2720 	Entering    spout    : 181088	Size: 0
# Machine: clarity26 Seq: 2720 	Leaving     spout    : 181237	Size: 160418
# Machine: clarity25 Seq: 2720 	Entering    scale    : 181294	Size: 0
# Machine: clarity25 Seq: 2720 	Leaving     scale    : 181372	Size: 60160
# Machine: clarity26 Seq: 2720 	Entering fat_features: 196712	Size: 0
# Machine: clarity26 Seq: 2720 	OpBegin  nl.tno.stormcv.operation.HaarCascadeOp: 196712	Size: 0
# Machine: clarity26 Seq: 2720 	OpEnd    nl.tno.stormcv.operation.HaarCascadeOp: 196798	Size: 0
# Machine: clarity26 Seq: 2720 	OpBegin  nl.tno.stormcv.operation.DnnForwardOp: 196798	Size: 0
# Machine: clarity26 Seq: 2720 	OpEnd    nl.tno.stormcv.operation.DnnForwardOp: 199071	Size: 0
# Machine: clarity26 Seq: 2720 	OpBegin  nl.tno.stormcv.operation.DnnClassifyOp: 199072	Size: 0
# Machine: clarity26 Seq: 2720 	OpEnd    nl.tno.stormcv.operation.DnnClassifyOp: 199072	Size: 0
# Machine: clarity26 Seq: 2720 	Leaving  fat_features: 199085	Size: 60465
# Machine: clarity25 Seq: 2720 	Entering    drawer   : 199137	Size: 0
# Machine: clarity25 Seq: 2720 	Leaving     drawer   : 199177	Size: 64241
# Machine: clarity25 Seq: 2720 	Entering   streamer  : 199189	Size: 0
# Machine: clarity25 Seq: 2720 	Leaving    streamer  : 199194	Size: 128482
# Machine: clarity26 Seq: 2720 	Ack          ack     : 199198	Size: 0
