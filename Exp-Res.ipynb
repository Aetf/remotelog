# %%
import analysis as ana
import matplotlib.pyplot as plt
import importlib as ilb
ilb.reload(ana)
# %matplotlib inline

# %% [markdown]
# # 2016-6-01

# %% [markdown]
# - 1: 32+32 cores, 2+40+2, 13 FPS
# - 2: 32+32 cores, 2+50+2, 13 FPS
# - 3: 32+32 cores, 2+60+2, 13 FPS [FG]
# - 4: 32+32 cores, 2+80+2, 13 FPS
# - 5: 32+32 cores, 2+100+2, 13 FPS

# %%
# %%capture capt
mul = ana.cross_res(*(['2016-6-01/{}'.format(i) for i in range(1,6)]))

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
mul.fps(ax=axs[0]).set_title('FPS')
mul.latency(ax=axs[1])[0].set_title('Latency')
# Out:
# WARNING: <exp 2016-6-01/2 nodes:2, FPS:13, topo: 2+50+2>: possibly bad data, latency values aren't stable. slope=0.235, intercept=2529.79, pvalue=2.01e-09, stderr=0.0389, sample_size=1856
# WARNING: <exp 2016-6-01/4 nodes:2, FPS:13, topo: 2+80+2>: possibly bad data, latency values aren't stable. slope=0.147, intercept=2464.82, pvalue=3.74e-06, stderr=0.0317, sample_size=1850

# %% [markdown]
# - 6: 32+32 cores, 2+40+2, 14 FPS
# - 7: 32+32 cores, 2+50+2, 14 FPS
# - 8: 32+32 cores, 2+60+2, 14 FPS
# - 9: 32+32 cores, 2+80+2, 14 FPS [FG]
# - 10: 32+32 cores, 2+100+2, 14 FPS
#
# __The following are invalid because fps does not actually reach specified value__
#
# - 11: 32+32 cores, 2+40+2, 15 FPS
# - 12: 32+32 cores, 2+50+2, 15 FPS
# - 13: 32+32 cores, 2+60+2, 15 FPS
# - 14: 32+32 cores, 2+80+2, 15 FPS
# - 15: 32+32 cores, 2+100+2, 15 FPS
#
# - 16: 32+32 cores, 2+40+2, 16 FPS
# - 17: 32+32 cores, 2+50+2, 16 FPS
# - 18: 32+32 cores, 2+60+2, 16 FPS
# - 19: 32+32 cores, 2+80+2, 16 FPS
# - 20: 32+32 cores, 2+100+2, 16 FPS
#
# - 21: 32+32 cores, 2+40+2, 18 FPS
# - 22: 32+32 cores, 2+50+2, 18 FPS
# - 23: 32+32 cores, 2+60+2, 18 FPS
# - 24: 32+32 cores, 2+80+2, 18 FPS
# - 25: 32+32 cores, 2+100+2, 18 FPS
#
# - 26: 32+32 cores, 2+40+2, 20 FPS
# - 27: 32+32 cores, 2+50+2, 20 FPS
# - 28: 32+32 cores, 2+60+2, 20 FPS
# - 29: 32+32 cores, 2+80+2, 20 FPS
# - 30: 32+32 cores, 2+100+2, 20 FPS

# %% [markdown]
# # 2016-6-02

# %% [markdown]
# - 1: 32+32 cores, 2+40+2, 17 FPS
# - 2: 32+32 cores, 2+100+2, 24 FPS
# - 3: 32+32 cores, 2+100+2, 34 FPS
#
#
# - 4: 32+32 cores, 2+40+2, 15 FPS
# - 5: 32+32 cores, 2+50+2, 15 FPS
# - 6: 32+32 cores, 2+60+2, 15 FPS
# - 7: 32+32 cores, 2+80+2, 15 FPS
# - 8: 32+32 cores, 2+100+2, 15 FPS
#
# - 9: 32+32 cores, 2+40+2, 16 FPS
# - 10: 32+32 cores, 2+50+2, 16 FPS
# - 11: 32+32 cores, 2+60+2, 16 FPS
# - 12: 32+32 cores, 2+80+2, 16 FPS
# - 13: 32+32 cores, 2+100+2, 16 FPS
#
# - 14: 32+32 cores, 2+40+2, 18 FPS
# - 15: 32+32 cores, 2+50+2, 18 FPS
# - 16: 32+32 cores, 2+60+2, 18 FPS
# - 17: 32+32 cores, 2+80+2, 18 FPS
# - 18: 32+32 cores, 2+100+2, 18 FPS
#
# - 19: 32+32 cores, 2+40+2, 20 FPS
# - 20: 32+32 cores, 2+50+2, 20 FPS
# - 21: 32+32 cores, 2+60+2, 20 FPS
# - 22: 32+32 cores, 2+80+2, 20 FPS
# - 23: 32+32 cores, 2+100+2, 20 FPS

# %% [markdown]
# # 2016-6-03

# %% [markdown]
# - 1: 32+32 cores, 2+40+2, 18 FPS with start-delay

# %% [markdown]
# ## Service time with low workload

# %% [markdown]
# ### 8 Cores

# %% [markdown]
# - 2: 8 cores, 1+5+1, 1 FPS
# - 3: 8 cores, 1+5+1, 2 FPS

# %%
# %%capture
ilb.reload(ana)
core8 = ana.cross_res('2016-6-03/2', '2016-6-03/3')

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
for idx in [0, 1]:
    p = core8.exps[idx].latency(ax=axs[idx])
    p.set_title('FPS = {}'.format(core8.exps[idx].params['fps']))

# %%
# %%asmarkdown
# print("""| FPS | Avg. latency |
# |:---:|:------------:|""")
# for exp in core8.exps:
#     print('|{}|{:.4f}ms|'.format(exp.params['fps'], exp.avg_latency()))
# Out:
# <p><table>
# <thead>
# <tr>
# <th align="center">FPS</th>
# <th align="center">Avg. latency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="center">1</td>
# <td align="center">1763.8662ms</td>
# </tr>
# <tr>
# <td align="center">2</td>
# <td align="center">1889.8658ms</td>
# </tr>
# </tbody>
# </table></p>

# %% [markdown]
# # 2016-6-07

# %% [markdown]
# ## Service time with low workload

# %% [markdown]
# | Cores | scale | fat_features | FPS     | Avg. Total Latency |
# |:-----:|:-----:|:------------:|:-------:|:------------------:|
# | 8     | 1     | 5            | 1       | 1763 ms            |
# | 8     | 1     | 5            | 2       | 1889 ms            |
# | 16    | 1     | 27           | 1       | 1743 ms            |
# | 16    | 1     | 27           | 2       | 1745 ms            |
# | 32    | 1     | 27           | 1       | 1724 ms            |
# | 32    | 1     | 27           | 2       | 1740 ms            |
# | 32+32 | 1     | 50           | 1       | 1730 ms            |
# | 32+32 | 2     | 50           | 1       | 1738 ms            |
# | 32+32 | 1     | 50           | 2       | 1736 ms            |
# | 32+32 | 2     | 50           | 2       | 1760 ms            |

# %% [markdown]
# ### 16 Cores

# %% [markdown]
# - 1: 16 cores, 1+27+1, 1 FPS
# - 2: 16 cores, 1+27+1, 2 FPS

# %%
# %%capture
core16 = ana.cross_res('2016-6-07/1', '2016-6-07/2')

# %%
# %%asmarkdown
# print("""| FPS | Avg. latency |
# |:---:|:------------:|""")
# for exp in core16.exps:
#     print('|{}|{:.4f}ms|'.format(exp.params['fps'], exp.avg_latency()))
# Out:
# <p><table>
# <thead>
# <tr>
# <th align="center">FPS</th>
# <th align="center">Avg. latency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="center">1</td>
# <td align="center">1743.9888ms</td>
# </tr>
# <tr>
# <td align="center">2</td>
# <td align="center">1745.9797ms</td>
# </tr>
# </tbody>
# </table></p>

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
for idx in [0, 1]:
    p = core16.exps[idx].latency(ax=axs[idx])
    p.set_title('FPS = {}'.format(core16.exps[idx].params['fps']))

# %% [markdown]
# ### 32 Cores

# %% [markdown]
# - 3: 32 cores, 1+27+1, 1 FPS
# - 4: 32 cores, 1+27+1, 2 FPS

# %%
# %%capture
core32 = ana.cross_res('2016-6-07/3', '2016-6-07/4')

# %%
# %%asmarkdown
# print("""| FPS | Avg. latency |
# |:---:|:------------:|""")
# for exp in core32.exps:
#     print('|{}|{:.4f}ms|'.format(exp.params['fps'], exp.avg_latency()))
# Out:
# <p><table>
# <thead>
# <tr>
# <th align="center">FPS</th>
# <th align="center">Avg. latency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="center">1</td>
# <td align="center">1724.2895ms</td>
# </tr>
# <tr>
# <td align="center">2</td>
# <td align="center">1740.4764ms</td>
# </tr>
# </tbody>
# </table></p>

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
for idx in [0, 1]:
    p = core32.exps[idx].latency(ax=axs[idx])
    p.set_title('FPS = {}'.format(core32.exps[idx].params['fps']))

# %% [markdown]
# ### 32 + 32 Cores

# %% [markdown]
# - 5: 32+32 cores, 1+50+1, 1 FPS
# - 6: 32+32 cores, 2+50+2, 1 FPS
# - 7: 32+32 cores, 1+50+1, 2 FPS
# - 8: 32+32 cores, 2+50+2, 2 FPS

# %%
# %%capture
core64 = ana.cross_res('2016-6-07/5', '2016-6-07/6', '2016-6-07/7', '2016-6-07/8')

# %%
# %%asmarkdown
# print("""|Scale | FPS | Avg. latency |
# |:----:|:---:|:------------:|""")
# for exp in core64.exps:
#     print('|{}|{}|{:.4f}ms|'.format(exp.params['scale'], exp.params['fps'], exp.avg_latency()))
# Out:
# <p><table>
# <thead>
# <tr>
# <th align="center">Scale</th>
# <th align="center">FPS</th>
# <th align="center">Avg. latency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="center">1</td>
# <td align="center">1</td>
# <td align="center">1730.3460ms</td>
# </tr>
# <tr>
# <td align="center">2</td>
# <td align="center">1</td>
# <td align="center">1738.3939ms</td>
# </tr>
# <tr>
# <td align="center">1</td>
# <td align="center">2</td>
# <td align="center">1736.8191ms</td>
# </tr>
# <tr>
# <td align="center">2</td>
# <td align="center">2</td>
# <td align="center">1760.3733ms</td>
# </tr>
# </tbody>
# </table></p>

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
for idx in [0, 1]:
    exp = core64.exps[idx]
    p = exp.latency(ax=axs[idx])
    p.set_title('Scale = {}, FPS = {}'.format(exp.params['scale'], exp.params['fps']))
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
for idx in [2, 3]:
    exp = core64.exps[idx]
    p = exp.latency(ax=axs[idx-2])
    p.set_title('Scale = {}, FPS = {}'.format(exp.params['scale'], exp.params['fps']))

# %% [markdown]
# ## Check if frames are only processed on the same machine when possible
# Conclusion: no, there are frames using scale on clarity__25__ but sent to fat_features on clatiry__26__ and vice versa

# %%
ilb.reload(ana)
res = ana.exp_res('2016-6-02/4')
res.show_log(2720)
# Out:
# Collect log from ['archive/2016-6-02/4/clarity25/dnn_classification-1-1464893993-worker-6721.log']
# Collect cpu log from archive/2016-6-02/4/clarity25/log.cpu
# Collect log from ['archive/2016-6-02/4/clarity26/dnn_classification-1-1464893993-worker-6721.log']
# Collect cpu log from archive/2016-6-02/4/clarity26/log.cpu
# WARNING: seq 72: consecutive entering on stage spout and scale with stamp difference 83
# WARNING: seq 3963: consecutive entering on stage drawer and streamer with stamp difference 47
# WARNING: seq 2721: consecutive entering on stage spout and scale with stamp difference 31
# Auto fixed cross stage timming issues for 110 log entries
# Dropped 0 frames
# Machine: clarity26 Seq: 2720 	Entering    spout    : 181088	Size: 0
# Machine: clarity26 Seq: 2720 	Leaving     spout    : 181237	Size: 160418
# Machine: clarity25 Seq: 2720 	Entering    scale    : 181294	Size: 0
# Machine: clarity25 Seq: 2720 	Leaving     scale    : 181372	Size: 60160
# Machine: clarity26 Seq: 2720 	Entering fat_features: 196712	Size: 0
# Machine: clarity26 Seq: 2720 	OpBegin  nl.tno.stormcv.operation.HaarCascadeOp: 196712	Size: 0
# Machine: clarity26 Seq: 2720 	OpEnd    nl.tno.stormcv.operation.HaarCascadeOp: 196798	Size: 0
# Machine: clarity26 Seq: 2720 	OpBegin  nl.tno.stormcv.operation.DnnForwardOp: 196798	Size: 0
# Machine: clarity26 Seq: 2720 	OpEnd    nl.tno.stormcv.operation.DnnForwardOp: 199071	Size: 0
# Machine: clarity26 Seq: 2720 	OpBegin  nl.tno.stormcv.operation.DnnClassifyOp: 199072	Size: 0
# Machine: clarity26 Seq: 2720 	OpEnd    nl.tno.stormcv.operation.DnnClassifyOp: 199072	Size: 0
# Machine: clarity26 Seq: 2720 	Leaving  fat_features: 199085	Size: 60465
# Machine: clarity25 Seq: 2720 	Entering    drawer   : 199137	Size: 0
# Machine: clarity25 Seq: 2720 	Leaving     drawer   : 199177	Size: 64241
# Machine: clarity25 Seq: 2720 	Entering   streamer  : 199189	Size: 0
# Machine: clarity25 Seq: 2720 	Leaving    streamer  : 199194	Size: 128482
# Machine: clarity26 Seq: 2720 	Ack          ack     : 199198	Size: 0

# %% [markdown]
# # 2016-6-08

# %% [markdown]
# - 1: 16 cores, 1+34+1, 7 FPS
# - 2: 16 cores, 1+36+1, 7 FPS
# - 3: 16 cores, 1+38+1, 7 FPS
# - 4: 16 cores, 1+48+1, 7 FPS
# - 5: 16 cores, 1+58+1, 7 FPS
# - 6: 16 cores, 1+68+1, 7 FPS

# %% [markdown]
# ## Max FPS with latency limit at 2.5s

# %% [markdown]
# | Cores | scale | fat_features | Max FPS | Avg. Total Latency |
# |:-----:|:-----:|:------------:|:-------:|:------------------:|
# | 8     | 1     | 20           | 3       | 1815 ms            |
# | 16    | 1     | 48           | 7       | 2049 ms            |
# | 32    | 1     | 30           | 6       | 2246 ms            |
# | 32+32 | 1     | 60           | 13      | 2470 ms            |
# | 32+32 | 2     | 80           | 11~12   | 2195 ms            |

# %% [markdown]
# ### 8 Cores

# %%
# %%capture
ilb.reload(ana)
mul8fps = ana.cross_res(*(['2016-5-23/{}'.format(i) for i in range(13,19)]), *(['2016-6-08/{}'.format(i) for i in range(32,36)]))
mul8fat = ana.cross_res(*(['2016-5-23/{}'.format(i) for i in [5, 11, 17, 23]]))

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
mul8fps.latency(ax=axs[0])[0].set_title('FPS = 3')
mul8fat.latency(x=('FPS', lambda exp: exp.params['fps']), ax=axs[1])[0].set_title('fat = 11')
# Out:
# WARNING: <exp 2016-5-23/13 nodes:1, FPS:3, topo: 1+3+1>: possibly bad data, latency values aren't stable. slope=218.964, intercept=2157.08, pvalue=0.00e+00, stderr=0.5216, sample_size=245
# WARNING: <exp 2016-5-23/14 nodes:1, FPS:3, topo: 1+5+1>: possibly bad data, latency values aren't stable. slope=14.585, intercept=3041.49, pvalue=6.45e-66, stderr=0.6596, sample_size=315
# WARNING: <exp 2016-6-08/34 nodes:1, FPS:3, topo: 1+18+1>: possibly bad data, latency values aren't stable. slope=0.105, intercept=1775.37, pvalue=2.58e-02, stderr=0.0470, sample_size=445
# WARNING: <exp 2016-5-23/23 nodes:1, FPS:4, topo: 1+11+1>: possibly bad data, latency values aren't stable. slope=15.317, intercept=3334.39, pvalue=7.57e-59, stderr=0.7988, sample_size=409

# %% [markdown]
# ### 16 Cores

# %%
# %%capture
ilb.reload(ana)
mul16fps = ana.cross_res(*(['2016-5-23/{}'.format(i) for i in range(31,37)]), *(['2016-6-08/{}'.format(i) for i in range(1,7)]))
mul16fat = ana.cross_res(*(['2016-6-08/{}'.format(i) for i in [4, 13, 14, 15, 16]]))

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
mul16fps.latency(ax=axs[0])[0].set_title('FPS = 7')
mul16fat.latency(x=('FPS', lambda exp: exp.params['fps']), ax=axs[1])[0].set_title('fat = 48')
# Out:
# WARNING: <exp 2016-6-08/14 nodes:1, FPS:8, topo: 1+48+1>: possibly bad data, latency values aren't stable. slope=9.532, intercept=6808.55, pvalue=0.00e+00, stderr=0.0798, sample_size=1154
# WARNING: <exp 2016-6-08/15 nodes:1, FPS:9, topo: 1+48+1>: possibly bad data, latency values aren't stable. slope=23.328, intercept=6653.46, pvalue=0.00e+00, stderr=0.0584, sample_size=1308
# WARNING: <exp 2016-6-08/16 nodes:1, FPS:10, topo: 1+48+1>: possibly bad data, latency values aren't stable. slope=35.237, intercept=7235.87, pvalue=0.00e+00, stderr=0.0484, sample_size=1450

# %% [markdown]
# __Strange thing__: the system seems being able to catch up the input (latency from 0.25-0.5 and from 0.5-0.75 has no significant diff)
#
# Then why is the high latency?

# %%
print(mul16fat.exps[2])
mul16fat.exps[2].seq_latency()
mul16fat.exps[2].avg_latency(detail=True)
# Out:
# <exp 2016-6-08/14 nodes:1, FPS:8, topo: 1+48+1>
# WARNING: <exp 2016-6-08/14 nodes:1, FPS:8, topo: 1+48+1>: possibly bad data, latency values aren't stable. slope=9.532, intercept=6808.55, pvalue=0.00e+00, stderr=0.0798, sample_size=1154
# 17996.253032928944

# %% [markdown]
# ### 32 Cores (more data needed for mul32fat)

# %%
# %%capture
ilb.reload(ana)
mul32fps = ana.cross_res(*(['2016-6-09/{}'.format(i) for i in range(6,12)]))
mul32fat = ana.cross_res(*(['2016-6-09/{}'.format(i) for i in [9, 15, 16, 17]]))

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
mul32fps.latency(ax=axs[0])[0].set_title('FPS = 6')
mul32fat.latency(x=('FPS', lambda exp: exp.params['fps']), ax=axs[1])[0].set_title('fat = 30')
# Out:
# WARNING: <exp 2016-6-09/6 nodes:1, FPS:6, topo: 1+27+1>: possibly bad data, latency values aren't stable. slope=0.327, intercept=1996.28, pvalue=9.49e-14, stderr=0.0433, sample_size=886
# WARNING: <exp 2016-6-09/10 nodes:1, FPS:6, topo: 1+31+1>: possibly bad data, latency values aren't stable. slope=0.505, intercept=1799.29, pvalue=3.27e-34, stderr=0.0397, sample_size=887
# WARNING: <exp 2016-6-09/11 nodes:1, FPS:6, topo: 1+32+1>: possibly bad data, latency values aren't stable. slope=0.180, intercept=2500.37, pvalue=2.41e-03, stderr=0.0592, sample_size=888

# %% [markdown]
# ### 32 + 32 Cores

# %% [markdown]
# #### Scale = 1

# %%
# %%capture
ilb.reload(ana)
mul64_1fps = ana.cross_res(*(['2016-5-26/{}'.format(i) for i in range(14,18)]), '2016-5-27/1', '2016-6-09/13', '2016-6-09/14')
mul64_1fat = ana.cross_res('2016-5-26/13', '2016-5-26/17', '2016-6-08/19', '2016-6-08/24', '2016-6-08/29')

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
mul64_1fps.latency(ax=axs[0])[0].set_title('FPS = 13')
mul64_1fat.latency(x=('FPS', lambda exp: exp.params['fps']), ax=axs[1])[0].set_title('fat = 60')
# Out:
# WARNING: <exp 2016-5-26/17 nodes:2, FPS:13, topo: 1+60+1>: possibly bad data, latency values aren't stable. slope=0.102, intercept=2317.31, pvalue=1.49e-04, stderr=0.0267, sample_size=1512
# WARNING: <exp 2016-5-26/13 nodes:2, FPS:12, topo: 1+60+1>: possibly bad data, latency values aren't stable. slope=0.103, intercept=2307.61, pvalue=2.72e-04, stderr=0.0283, sample_size=1397
# WARNING: <exp 2016-5-26/17 nodes:2, FPS:13, topo: 1+60+1>: possibly bad data, latency values aren't stable. slope=0.102, intercept=2317.31, pvalue=1.49e-04, stderr=0.0267, sample_size=1512
# WARNING: <exp 2016-6-08/19 nodes:2, FPS:14, topo: 1+60+1>: possibly bad data, latency values aren't stable. slope=2.634, intercept=6182.60, pvalue=0.00e+00, stderr=0.0276, sample_size=2048
# WARNING: <exp 2016-6-08/24 nodes:2, FPS:15, topo: 1+60+1>: possibly bad data, latency values aren't stable. slope=2.717, intercept=13866.79, pvalue=0.00e+00, stderr=0.0291, sample_size=2198
# WARNING: <exp 2016-6-08/29 nodes:2, FPS:16, topo: 1+60+1>: possibly bad data, latency values aren't stable. slope=6.268, intercept=14801.53, pvalue=0.00e+00, stderr=0.0198, sample_size=2352

# %% [markdown]
# __An interesting case__: 32+32 cores, 1+80+1, 14 FPS, 10min

# %%
res = ana.exp_res('2016-6-09/12')
res.seq_latency()
res.avg_latency()
# Out:
# Collect log from ['archive/2016-6-09/12/clarity25/dnn_classification-1-1465503429-worker-6721.log']
# Collect cpu log from archive/2016-6-09/12/clarity25/log.cpu
# Collect log from ['archive/2016-6-09/12/clarity26/dnn_classification-1-1465503429-worker-6721.log']
# Collect cpu log from archive/2016-6-09/12/clarity26/log.cpu
# Auto fixed cross stage timming issues for 36 log entries
# Dropped 0 frames
# WARNING: <exp 2016-6-09/12 nodes:2, FPS:14, topo: 1+80+1>: possibly bad data, latency values aren't stable. slope=0.414, intercept=2082.40, pvalue=0.00e+00, stderr=0.0085, sample_size=4153
# 3802.0452684806164

# %% [markdown]
# #### Scale = 2

# %%
# %%capture
ilb.reload(ana)
mul64_2fps = ana.cross_res(*(['2016-6-07/{}'.format(i) for i in range(14,19)]))
mul64_2fat = ana.cross_res(*(['2016-6-07/{}'.format(i) for i in [12, 17, 22]]), *(['2016-6-02/{}'.format(i) for i in [7, 12, 17, 22]]))

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
mul64_2fps.latency(ax=axs[0])[0].set_title('FPS = 11')
p, df = mul64_2fat.latency(x=('FPS', lambda exp: exp.params['fps']), ax=axs[1])
p.set_title('fat = 80')

# %% [markdown]
# TODO: p value test not work for this, why?

# %%
mul64_2fps.exps[3].seq_latency()
mul64_2fps.exps[3].avg_latency()

# %% [markdown]
# # 2016-6-15

# %% [markdown]
# ## Non-periodic high latencies
#
# There are frames that are having abnormal high latency compared to its neighboor frames. A typical instance of this can be viewed clearly with the configuration `<exp 2016-5-26/17 nodes:2, FPS:13, topo: 1+60+1>`

# %%
# %%capture
ilb.reload(ana)
non_perio_res = ana.exp_res('2016-5-26/17')

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15,5))
non_perio_res.seq_latency(ax=axs[0])
non_perio_res.seq_latency(seq=range(1198,1204), ax=axs[1])

# %%
for frame_seq in [1199, 1200, 1201]:
    fig, axs = plt.subplots(ncols=2, figsize=(15,5))
    non_perio_res.latency(seq=frame_seq, ax=axs[0])
    non_perio_res.latency(seq=frame_seq, latencies=['Op:HaarCascadeOp', 'Op:DnnForwardOp', 'Op:DnnClassifyOp'], ax=axs[1])

# %% [markdown]
# ### Try setting fat_features to have highest kernel priority

# %% [markdown]
# - 1: 32+32 cores, 1+60+1, 13 FPS, nice fat_features
# - 2: 32+32 cores, 1+60+1, 13 FPS, nice fat_features
# - 3: 32+32 cores, 1+60+1, 13 FPS, nice fat_features

# %%
# %%capture
nice_fats = ana.cross_res('2016-6-15/1', '2016-6-15/2', '2016-6-15/3')

# %%
for exp in nice_fats.exps:
    exp.seq_latency()

# %%
nice_fats.exps[0].latency(1199)
nice_fats.exps[0].latency(1200)

# %% [markdown]
# # 2016-6-20

# %% [markdown]
# ## Porting fat_features to Caffe done

# %%
# %%capture
ilb.reload(ana)
caffe_cpu = ana.cross_res('2016-6-20/1', '2016-6-20/2', '2016-6-20/3')

# %%
for exp in caffe_cpu.exps:
    fig, axs = plt.subplots(ncols=2, figsize=(15,5))
    exp.latency(ax=axs[0])

# %%
ilb.reload(ana)
gpu = ana.exp_res('2016-7-05/2')
# Out:
# Collect log from ['archive/2016-7-05/2/localhost/dnn_classification-1-1467747358-worker-6700.log', 'archive/2016-7-05/2/localhost/dnn_classification-1-1467747358-worker-6700.log.metrics.log']
# Collect cpu log from archive/2016-7-05/2/localhost/log.cpu
# WARNING: seq 2554: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2172: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3607: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2814: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 3440: consecutive leaving on stage spout and spout with stamp difference 99
# WARNING: seq 2407: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 3033: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3700: consecutive leaving on stage spout and spout with stamp difference 340
# WARNING: seq 2651: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 1665: consecutive leaving on stage spout and spout with stamp difference 59
# WARNING: seq 3293: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2244: consecutive leaving on stage spout and spout with stamp difference 132
# WARNING: seq 2886: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3512: consecutive leaving on stage spout and spout with stamp difference 47
# WARNING: seq 2479: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3130: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3772: consecutive leaving on stage spout and spout with stamp difference 102
# WARNING: seq 2723: consecutive leaving on stage spout and spout with stamp difference 138
# WARNING: seq 1993: consecutive leaving on stage spout and spout with stamp difference 74
# WARNING: seq 3365: consecutive leaving on stage spout and spout with stamp difference 167
# WARNING: seq 2316: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2958: consecutive leaving on stage spout and spout with stamp difference 88
# WARNING: seq 3609: consecutive leaving on stage spout and spout with stamp difference 129
# WARNING: seq 2560: consecutive leaving on stage spout and spout with stamp difference 109
# WARNING: seq 3202: consecutive leaving on stage spout and spout with stamp difference 98
# WARNING: seq 2409: consecutive leaving on stage spout and spout with stamp difference 104
# WARNING: seq 3051: consecutive leaving on stage spout and spout with stamp difference 104
# WARNING: seq 2669: consecutive leaving on stage spout and spout with stamp difference 46
# WARNING: seq 1683: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3311: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 2262: consecutive leaving on stage spout and spout with stamp difference 90
# WARNING: seq 2888: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3530: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2481: consecutive leaving on stage spout and spout with stamp difference 80
# WARNING: seq 3148: consecutive leaving on stage spout and spout with stamp difference 57
# WARNING: seq 3790: consecutive leaving on stage spout and spout with stamp difference 160
# WARNING: seq 2741: consecutive leaving on stage spout and spout with stamp difference 182
# WARNING: seq 2011: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 3383: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1629: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 2334: consecutive leaving on stage spout and spout with stamp difference 159
# WARNING: seq 2960: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3627: consecutive leaving on stage spout and spout with stamp difference 150
# WARNING: seq 2578: consecutive leaving on stage spout and spout with stamp difference 186
# WARNING: seq 1848: consecutive leaving on stage spout and spout with stamp difference 119
# WARNING: seq 3220: consecutive leaving on stage spout and spout with stamp difference 138
# WARNING: seq 2427: consecutive leaving on stage spout and spout with stamp difference 55
# WARNING: seq 3069: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2687: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1701: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 1701: consecutive leaving on stage scale and scale with stamp difference 74
# WARNING: seq 3313: consecutive leaving on stage spout and spout with stamp difference 70
# WARNING: seq 2264: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 2906: consecutive leaving on stage spout and spout with stamp difference 141
# WARNING: seq 1920: consecutive leaving on stage spout and spout with stamp difference 50
# WARNING: seq 3548: consecutive leaving on stage spout and spout with stamp difference 92
# WARNING: seq 2499: consecutive leaving on stage spout and spout with stamp difference 210
# WARNING: seq 3166: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2117: consecutive leaving on stage spout and spout with stamp difference 96
# WARNING: seq 3792: consecutive leaving on stage spout and spout with stamp difference 96
# WARNING: seq 2759: consecutive leaving on stage spout and spout with stamp difference 53
# WARNING: seq 2029: consecutive leaving on stage spout and spout with stamp difference 46
# WARNING: seq 3385: consecutive leaving on stage spout and spout with stamp difference 148
# WARNING: seq 1647: consecutive leaving on stage spout and spout with stamp difference 160
# WARNING: seq 2336: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2978: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3645: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 2596: consecutive leaving on stage spout and spout with stamp difference 75
# WARNING: seq 1866: consecutive leaving on stage spout and spout with stamp difference 148
# WARNING: seq 3238: consecutive leaving on stage spout and spout with stamp difference 91
# WARNING: seq 2189: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2831: consecutive leaving on stage spout and spout with stamp difference 69
# WARNING: seq 3457: consecutive leaving on stage spout and spout with stamp difference 107
# WARNING: seq 1719: consecutive leaving on stage spout and spout with stamp difference 102
# WARNING: seq 1719: consecutive leaving on stage scale and scale with stamp difference 76
# WARNING: seq 3075: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2282: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3717: consecutive leaving on stage spout and spout with stamp difference 130
# WARNING: seq 2924: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 1938: consecutive leaving on stage spout and spout with stamp difference 93
# WARNING: seq 3566: consecutive leaving on stage spout and spout with stamp difference 93
# WARNING: seq 2517: consecutive leaving on stage spout and spout with stamp difference 48
# WARNING: seq 3168: consecutive leaving on stage spout and spout with stamp difference 133
# WARNING: seq 2135: consecutive leaving on stage spout and spout with stamp difference 75
# WARNING: seq 3810: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2761: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2047: consecutive leaving on stage spout and spout with stamp difference 102
# WARNING: seq 3403: consecutive leaving on stage spout and spout with stamp difference 475
# WARNING: seq 1649: consecutive leaving on stage spout and spout with stamp difference 101
# WARNING: seq 2354: consecutive leaving on stage spout and spout with stamp difference 177
# WARNING: seq 2996: consecutive leaving on stage spout and spout with stamp difference 140
# WARNING: seq 3663: consecutive leaving on stage spout and spout with stamp difference 47
# WARNING: seq 2614: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1884: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3240: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2207: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 2833: consecutive leaving on stage spout and spout with stamp difference 161
# WARNING: seq 3475: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 1721: consecutive leaving on stage spout and spout with stamp difference 62
# WARNING: seq 1721: consecutive leaving on stage scale and scale with stamp difference 84
# WARNING: seq 3093: consecutive leaving on stage spout and spout with stamp difference 371
# WARNING: seq 2300: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3735: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2942: consecutive leaving on stage spout and spout with stamp difference 92
# WARNING: seq 1956: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3568: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 2535: consecutive leaving on stage spout and spout with stamp difference 115
# WARNING: seq 3186: consecutive leaving on stage spout and spout with stamp difference 175
# WARNING: seq 2137: consecutive leaving on stage spout and spout with stamp difference 163
# WARNING: seq 2779: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3421: consecutive leaving on stage spout and spout with stamp difference 155
# WARNING: seq 2372: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3014: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3665: consecutive leaving on stage spout and spout with stamp difference 153
# WARNING: seq 2616: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 1902: consecutive leaving on stage spout and spout with stamp difference 157
# WARNING: seq 3258: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2209: consecutive leaving on stage spout and spout with stamp difference 110
# WARNING: seq 2851: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3493: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 2444: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3111: consecutive leaving on stage spout and spout with stamp difference 57
# WARNING: seq 2062: consecutive leaving on stage spout and spout with stamp difference 133
# WARNING: seq 3737: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 2688: consecutive leaving on stage spout and spout with stamp difference 153
# WARNING: seq 1974: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3330: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2537: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 2155: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 3590: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 2797: consecutive leaving on stage spout and spout with stamp difference 211
# WARNING: seq 3439: consecutive leaving on stage spout and spout with stamp difference 56
# WARNING: seq 2390: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 3016: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3683: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2634: consecutive leaving on stage spout and spout with stamp difference 110
# WARNING: seq 1904: consecutive leaving on stage spout and spout with stamp difference 119
# WARNING: seq 3276: consecutive leaving on stage spout and spout with stamp difference 160
# WARNING: seq 2227: consecutive leaving on stage spout and spout with stamp difference 156
# WARNING: seq 2869: consecutive leaving on stage spout and spout with stamp difference 232
# WARNING: seq 3511: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 2462: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3113: consecutive leaving on stage spout and spout with stamp difference 156
# WARNING: seq 2064: consecutive leaving on stage spout and spout with stamp difference 83
# WARNING: seq 3755: consecutive leaving on stage spout and spout with stamp difference 102
# WARNING: seq 2706: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 1976: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3348: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2555: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 2173: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3592: consecutive leaving on stage spout and spout with stamp difference 150
# WARNING: seq 2815: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3441: consecutive leaving on stage spout and spout with stamp difference 158
# WARNING: seq 2392: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 3034: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3701: consecutive leaving on stage spout and spout with stamp difference 285
# WARNING: seq 2652: consecutive leaving on stage spout and spout with stamp difference 49
# WARNING: seq 1666: consecutive leaving on stage spout and spout with stamp difference 101
# WARNING: seq 3294: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2245: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2887: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3513: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 2464: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3131: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3773: consecutive leaving on stage spout and spout with stamp difference 144
# WARNING: seq 2724: consecutive leaving on stage spout and spout with stamp difference 180
# WARNING: seq 1994: consecutive leaving on stage spout and spout with stamp difference 117
# WARNING: seq 3366: consecutive leaving on stage spout and spout with stamp difference 49
# WARNING: seq 2317: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 2959: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 3610: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2561: consecutive leaving on stage spout and spout with stamp difference 152
# WARNING: seq 1847: consecutive leaving on stage spout and spout with stamp difference 51
# WARNING: seq 3203: consecutive leaving on stage spout and spout with stamp difference 163
# WARNING: seq 2410: consecutive leaving on stage spout and spout with stamp difference 146
# WARNING: seq 3052: consecutive leaving on stage spout and spout with stamp difference 146
# WARNING: seq 2670: consecutive leaving on stage spout and spout with stamp difference 88
# WARNING: seq 1684: consecutive leaving on stage spout and spout with stamp difference 131
# WARNING: seq 3296: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 2263: consecutive leaving on stage spout and spout with stamp difference 132
# WARNING: seq 2889: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 3531: consecutive leaving on stage spout and spout with stamp difference 56
# WARNING: seq 2482: consecutive leaving on stage spout and spout with stamp difference 122
# WARNING: seq 3149: consecutive leaving on stage spout and spout with stamp difference 99
# WARNING: seq 3791: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 2742: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2012: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 3368: consecutive leaving on stage spout and spout with stamp difference 180
# WARNING: seq 1630: consecutive leaving on stage spout and spout with stamp difference 101
# WARNING: seq 2335: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2961: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3628: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2579: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 1849: consecutive leaving on stage spout and spout with stamp difference 161
# WARNING: seq 3221: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 2428: consecutive leaving on stage spout and spout with stamp difference 98
# WARNING: seq 3070: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2672: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1702: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1702: consecutive leaving on stage scale and scale with stamp difference 78
# WARNING: seq 3314: consecutive leaving on stage spout and spout with stamp difference 111
# WARNING: seq 2265: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2907: consecutive leaving on stage spout and spout with stamp difference 99
# WARNING: seq 1921: consecutive leaving on stage spout and spout with stamp difference 92
# WARNING: seq 3549: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 2500: consecutive leaving on stage spout and spout with stamp difference 74
# WARNING: seq 3167: consecutive leaving on stage spout and spout with stamp difference 91
# WARNING: seq 2118: consecutive leaving on stage spout and spout with stamp difference 142
# WARNING: seq 3793: consecutive leaving on stage spout and spout with stamp difference 138
# WARNING: seq 2744: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 2030: consecutive leaving on stage spout and spout with stamp difference 88
# WARNING: seq 3386: consecutive leaving on stage spout and spout with stamp difference 47
# WARNING: seq 1632: consecutive leaving on stage spout and spout with stamp difference 122
# WARNING: seq 2337: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 2979: consecutive leaving on stage spout and spout with stamp difference 169
# WARNING: seq 3646: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2597: consecutive leaving on stage spout and spout with stamp difference 116
# WARNING: seq 1867: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3239: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 2190: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2816: consecutive leaving on stage spout and spout with stamp difference 107
# WARNING: seq 3458: consecutive leaving on stage spout and spout with stamp difference 162
# WARNING: seq 1704: consecutive leaving on stage spout and spout with stamp difference 53
# WARNING: seq 3076: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2283: consecutive leaving on stage spout and spout with stamp difference 173
# WARNING: seq 3718: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 2925: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1939: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3567: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 2518: consecutive leaving on stage spout and spout with stamp difference 99
# WARNING: seq 3169: consecutive leaving on stage spout and spout with stamp difference 175
# WARNING: seq 2120: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3811: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2762: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2032: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3404: consecutive leaving on stage spout and spout with stamp difference 517
# WARNING: seq 1650: consecutive leaving on stage spout and spout with stamp difference 174
# WARNING: seq 2355: consecutive leaving on stage spout and spout with stamp difference 47
# WARNING: seq 2997: consecutive leaving on stage spout and spout with stamp difference 59
# WARNING: seq 3648: consecutive leaving on stage spout and spout with stamp difference 140
# WARNING: seq 2615: consecutive leaving on stage spout and spout with stamp difference 125
# WARNING: seq 1885: consecutive leaving on stage spout and spout with stamp difference 180
# WARNING: seq 3241: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2192: consecutive leaving on stage spout and spout with stamp difference 113
# WARNING: seq 2834: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3476: consecutive leaving on stage spout and spout with stamp difference 87
# WARNING: seq 1722: consecutive leaving on stage spout and spout with stamp difference 104
# WARNING: seq 1722: consecutive leaving on stage scale and scale with stamp difference 90
# WARNING: seq 3094: consecutive leaving on stage spout and spout with stamp difference 413
# WARNING: seq 2301: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3720: consecutive leaving on stage spout and spout with stamp difference 130
# WARNING: seq 2943: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 1957: consecutive leaving on stage spout and spout with stamp difference 99
# WARNING: seq 3569: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 2520: consecutive leaving on stage spout and spout with stamp difference 58
# WARNING: seq 3187: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2138: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2780: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 3422: consecutive leaving on stage spout and spout with stamp difference 55
# WARNING: seq 2373: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 3015: consecutive leaving on stage spout and spout with stamp difference 169
# WARNING: seq 3666: consecutive leaving on stage spout and spout with stamp difference 62
# WARNING: seq 2617: consecutive leaving on stage spout and spout with stamp difference 100
# WARNING: seq 1903: consecutive leaving on stage spout and spout with stamp difference 77
# WARNING: seq 3259: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 2210: consecutive leaving on stage spout and spout with stamp difference 173
# WARNING: seq 2852: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3494: consecutive leaving on stage spout and spout with stamp difference 166
# WARNING: seq 2445: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3096: consecutive leaving on stage spout and spout with stamp difference 299
# WARNING: seq 2063: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3738: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2689: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 1975: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3331: consecutive leaving on stage spout and spout with stamp difference 96
# WARNING: seq 2538: consecutive leaving on stage spout and spout with stamp difference 108
# WARNING: seq 2156: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 3591: consecutive leaving on stage spout and spout with stamp difference 101
# WARNING: seq 2798: consecutive leaving on stage spout and spout with stamp difference 53
# WARNING: seq 3424: consecutive leaving on stage spout and spout with stamp difference 160
# WARNING: seq 2391: consecutive leaving on stage spout and spout with stamp difference 49
# WARNING: seq 3017: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3684: consecutive leaving on stage spout and spout with stamp difference 96
# WARNING: seq 2635: consecutive leaving on stage spout and spout with stamp difference 48
# WARNING: seq 1905: consecutive leaving on stage spout and spout with stamp difference 162
# WARNING: seq 3277: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2228: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2870: consecutive leaving on stage spout and spout with stamp difference 285
# WARNING: seq 3496: consecutive leaving on stage spout and spout with stamp difference 90
# WARNING: seq 2463: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 3114: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 2065: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 3756: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 2707: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 1977: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3349: consecutive leaving on stage spout and spout with stamp difference 59
# WARNING: seq 2556: consecutive leaving on stage spout and spout with stamp difference 41
# WARNING: seq 2174: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 3593: consecutive leaving on stage spout and spout with stamp difference 56
# WARNING: seq 2800: consecutive leaving on stage spout and spout with stamp difference 138
# WARNING: seq 3442: consecutive leaving on stage spout and spout with stamp difference 46
# WARNING: seq 2393: consecutive leaving on stage spout and spout with stamp difference 156
# WARNING: seq 3035: consecutive leaving on stage spout and spout with stamp difference 135
# WARNING: seq 3702: consecutive leaving on stage spout and spout with stamp difference 328
# WARNING: seq 2653: consecutive leaving on stage spout and spout with stamp difference 91
# WARNING: seq 1667: consecutive leaving on stage spout and spout with stamp difference 193
# WARNING: seq 1667: consecutive leaving on stage scale and scale with stamp difference 75
# WARNING: seq 3295: consecutive leaving on stage spout and spout with stamp difference 141
# WARNING: seq 2246: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2872: consecutive leaving on stage spout and spout with stamp difference 243
# WARNING: seq 3514: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 2465: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3132: consecutive leaving on stage spout and spout with stamp difference 113
# WARNING: seq 3774: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2725: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1995: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 3367: consecutive leaving on stage spout and spout with stamp difference 96
# WARNING: seq 2318: consecutive leaving on stage spout and spout with stamp difference 50
# WARNING: seq 2944: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 3611: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2562: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3204: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2411: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 3053: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3704: consecutive leaving on stage spout and spout with stamp difference 235
# WARNING: seq 2671: consecutive leaving on stage spout and spout with stamp difference 144
# WARNING: seq 1685: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1685: consecutive leaving on stage scale and scale with stamp difference 74
# WARNING: seq 3297: consecutive leaving on stage spout and spout with stamp difference 100
# WARNING: seq 2248: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 2890: consecutive leaving on stage spout and spout with stamp difference 78
# WARNING: seq 3532: consecutive leaving on stage spout and spout with stamp difference 101
# WARNING: seq 2483: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3150: consecutive leaving on stage spout and spout with stamp difference 162
# WARNING: seq 3776: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 2743: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2013: consecutive leaving on stage spout and spout with stamp difference 111
# WARNING: seq 3369: consecutive leaving on stage spout and spout with stamp difference 53
# WARNING: seq 1631: consecutive leaving on stage spout and spout with stamp difference 70
# WARNING: seq 2320: consecutive leaving on stage spout and spout with stamp difference 183
# WARNING: seq 2962: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 3629: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2580: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1850: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3222: consecutive leaving on stage spout and spout with stamp difference 98
# WARNING: seq 2429: consecutive leaving on stage spout and spout with stamp difference 140
# WARNING: seq 3071: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 2673: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 1703: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3315: consecutive leaving on stage spout and spout with stamp difference 153
# WARNING: seq 2266: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 2908: consecutive leaving on stage spout and spout with stamp difference 146
# WARNING: seq 1922: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 3550: consecutive leaving on stage spout and spout with stamp difference 175
# WARNING: seq 2501: consecutive leaving on stage spout and spout with stamp difference 125
# WARNING: seq 3152: consecutive leaving on stage spout and spout with stamp difference 109
# WARNING: seq 2119: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3794: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 2745: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2031: consecutive leaving on stage spout and spout with stamp difference 166
# WARNING: seq 3387: consecutive leaving on stage spout and spout with stamp difference 108
# WARNING: seq 1633: consecutive leaving on stage spout and spout with stamp difference 168
# WARNING: seq 2338: consecutive leaving on stage spout and spout with stamp difference 63
# WARNING: seq 2980: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3647: consecutive leaving on stage spout and spout with stamp difference 98
# WARNING: seq 2598: consecutive leaving on stage spout and spout with stamp difference 158
# WARNING: seq 1868: consecutive leaving on stage spout and spout with stamp difference 110
# WARNING: seq 3224: consecutive leaving on stage spout and spout with stamp difference 124
# WARNING: seq 2191: consecutive leaving on stage spout and spout with stamp difference 71
# WARNING: seq 2817: consecutive leaving on stage spout and spout with stamp difference 68
# WARNING: seq 3459: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 1705: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 3077: consecutive leaving on stage spout and spout with stamp difference 156
# WARNING: seq 2284: consecutive leaving on stage spout and spout with stamp difference 220
# WARNING: seq 3719: consecutive leaving on stage spout and spout with stamp difference 87
# WARNING: seq 2926: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 1940: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3552: consecutive leaving on stage spout and spout with stamp difference 92
# WARNING: seq 2519: consecutive leaving on stage spout and spout with stamp difference 146
# WARNING: seq 3170: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2121: consecutive leaving on stage spout and spout with stamp difference 65
# WARNING: seq 3812: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 2763: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 2033: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3405: consecutive leaving on stage spout and spout with stamp difference 359
# WARNING: seq 1651: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 2356: consecutive leaving on stage spout and spout with stamp difference 91
# WARNING: seq 2998: consecutive leaving on stage spout and spout with stamp difference 117
# WARNING: seq 3649: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2600: consecutive leaving on stage spout and spout with stamp difference 111
# WARNING: seq 1886: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3242: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 2193: consecutive leaving on stage spout and spout with stamp difference 155
# WARNING: seq 2835: consecutive leaving on stage spout and spout with stamp difference 89
# WARNING: seq 3477: consecutive leaving on stage spout and spout with stamp difference 141
# WARNING: seq 3095: consecutive leaving on stage spout and spout with stamp difference 257
# WARNING: seq 2302: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3721: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2928: consecutive leaving on stage spout and spout with stamp difference 119
# WARNING: seq 1958: consecutive leaving on stage spout and spout with stamp difference 141
# WARNING: seq 3570: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 2521: consecutive leaving on stage spout and spout with stamp difference 109
# WARNING: seq 3188: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2139: consecutive leaving on stage spout and spout with stamp difference 99
# WARNING: seq 2781: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3423: consecutive leaving on stage spout and spout with stamp difference 105
# WARNING: seq 2374: consecutive leaving on stage spout and spout with stamp difference 50
# WARNING: seq 3000: consecutive leaving on stage spout and spout with stamp difference 108
# WARNING: seq 3667: consecutive leaving on stage spout and spout with stamp difference 106
# WARNING: seq 2618: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 1888: consecutive leaving on stage spout and spout with stamp difference 146
# WARNING: seq 3260: consecutive leaving on stage spout and spout with stamp difference 70
# WARNING: seq 2211: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2853: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 3495: consecutive leaving on stage spout and spout with stamp difference 49
# WARNING: seq 2446: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 3097: consecutive leaving on stage spout and spout with stamp difference 140
# WARNING: seq 2048: consecutive leaving on stage spout and spout with stamp difference 162
# WARNING: seq 3739: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2690: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1960: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3332: consecutive leaving on stage spout and spout with stamp difference 138
# WARNING: seq 2539: consecutive leaving on stage spout and spout with stamp difference 58
# WARNING: seq 2157: consecutive leaving on stage spout and spout with stamp difference 135
# WARNING: seq 2799: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 3425: consecutive leaving on stage spout and spout with stamp difference 53
# WARNING: seq 2376: consecutive leaving on stage spout and spout with stamp difference 133
# WARNING: seq 3018: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 3685: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2636: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 1906: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3278: consecutive leaving on stage spout and spout with stamp difference 87
# WARNING: seq 2229: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2871: consecutive leaving on stage spout and spout with stamp difference 201
# WARNING: seq 3497: consecutive leaving on stage spout and spout with stamp difference 131
# WARNING: seq 2448: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3115: consecutive leaving on stage spout and spout with stamp difference 193
# WARNING: seq 2066: consecutive leaving on stage spout and spout with stamp difference 117
# WARNING: seq 3757: consecutive leaving on stage spout and spout with stamp difference 58
# WARNING: seq 2708: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 1978: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3350: consecutive leaving on stage spout and spout with stamp difference 104
# WARNING: seq 2557: consecutive leaving on stage spout and spout with stamp difference 83
# WARNING: seq 2175: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 3594: consecutive leaving on stage spout and spout with stamp difference 115
# WARNING: seq 2801: consecutive leaving on stage spout and spout with stamp difference 57
# WARNING: seq 3443: consecutive leaving on stage spout and spout with stamp difference 87
# WARNING: seq 2394: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3036: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 3703: consecutive leaving on stage spout and spout with stamp difference 394
# WARNING: seq 2654: consecutive leaving on stage spout and spout with stamp difference 133
# WARNING: seq 1668: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3280: consecutive leaving on stage spout and spout with stamp difference 104
# WARNING: seq 2247: consecutive leaving on stage spout and spout with stamp difference 53
# WARNING: seq 2873: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3515: consecutive leaving on stage spout and spout with stamp difference 67
# WARNING: seq 2466: consecutive leaving on stage spout and spout with stamp difference 177
# WARNING: seq 3133: consecutive leaving on stage spout and spout with stamp difference 155
# WARNING: seq 3775: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2726: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 1996: consecutive leaving on stage spout and spout with stamp difference 87
# WARNING: seq 3352: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 2319: consecutive leaving on stage spout and spout with stamp difference 116
# WARNING: seq 2945: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 3612: consecutive leaving on stage spout and spout with stamp difference 130
# WARNING: seq 2563: consecutive leaving on stage spout and spout with stamp difference 103
# WARNING: seq 3205: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2412: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3054: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3705: consecutive leaving on stage spout and spout with stamp difference 277
# WARNING: seq 2656: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 1686: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 3298: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 2249: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 2891: consecutive leaving on stage spout and spout with stamp difference 120
# WARNING: seq 3533: consecutive leaving on stage spout and spout with stamp difference 142
# WARNING: seq 2484: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3151: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3777: consecutive leaving on stage spout and spout with stamp difference 60
# WARNING: seq 2728: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 2014: consecutive leaving on stage spout and spout with stamp difference 155
# WARNING: seq 3370: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 2321: consecutive leaving on stage spout and spout with stamp difference 48
# WARNING: seq 2963: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3630: consecutive leaving on stage spout and spout with stamp difference 97
# WARNING: seq 2581: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 1851: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3223: consecutive leaving on stage spout and spout with stamp difference 65
# WARNING: seq 2430: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 3056: consecutive leaving on stage spout and spout with stamp difference 125
# WARNING: seq 2674: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 1688: consecutive leaving on stage spout and spout with stamp difference 105
# WARNING: seq 3316: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2267: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2909: consecutive leaving on stage spout and spout with stamp difference 209
# WARNING: seq 1923: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3551: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2502: consecutive leaving on stage spout and spout with stamp difference 166
# WARNING: seq 3153: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2104: consecutive leaving on stage spout and spout with stamp difference 173
# WARNING: seq 3795: consecutive leaving on stage spout and spout with stamp difference 87
# WARNING: seq 2746: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2016: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3388: consecutive leaving on stage spout and spout with stamp difference 150
# WARNING: seq 1634: consecutive leaving on stage spout and spout with stamp difference 46
# WARNING: seq 2339: consecutive leaving on stage spout and spout with stamp difference 105
# WARNING: seq 2981: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3632: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 2599: consecutive leaving on stage spout and spout with stamp difference 64
# WARNING: seq 1869: consecutive leaving on stage spout and spout with stamp difference 58
# WARNING: seq 3225: consecutive leaving on stage spout and spout with stamp difference 167
# WARNING: seq 2176: consecutive leaving on stage spout and spout with stamp difference 97
# WARNING: seq 2818: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 3460: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1706: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 1706: consecutive leaving on stage scale and scale with stamp difference 74
# WARNING: seq 3078: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2285: consecutive leaving on stage spout and spout with stamp difference 83
# WARNING: seq 2927: consecutive leaving on stage spout and spout with stamp difference 77
# WARNING: seq 1941: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3553: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 2504: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3171: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2122: consecutive leaving on stage spout and spout with stamp difference 109
# WARNING: seq 3813: consecutive leaving on stage spout and spout with stamp difference 66
# WARNING: seq 2764: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 2034: consecutive leaving on stage spout and spout with stamp difference 129
# WARNING: seq 3406: consecutive leaving on stage spout and spout with stamp difference 401
# WARNING: seq 1652: consecutive leaving on stage spout and spout with stamp difference 112
# WARNING: seq 2357: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 2999: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3650: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2601: consecutive leaving on stage spout and spout with stamp difference 174
# ...
# WARNING: seq 2223: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2849: consecutive leaving on stage spout and spout with stamp difference 108
# WARNING: seq 3491: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 2442: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 3109: consecutive leaving on stage spout and spout with stamp difference 52
# WARNING: seq 2060: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3751: consecutive leaving on stage spout and spout with stamp difference 140
# WARNING: seq 2702: consecutive leaving on stage spout and spout with stamp difference 157
# WARNING: seq 1972: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 3328: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2551: consecutive leaving on stage spout and spout with stamp difference 54
# WARNING: seq 2153: consecutive leaving on stage spout and spout with stamp difference 117
# WARNING: seq 3588: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2795: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 3437: consecutive leaving on stage spout and spout with stamp difference 87
# WARNING: seq 2388: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3030: consecutive leaving on stage spout and spout with stamp difference 68
# WARNING: seq 3681: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2632: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 1918: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3274: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2225: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2867: consecutive leaving on stage spout and spout with stamp difference 330
# WARNING: seq 3509: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2460: consecutive leaving on stage spout and spout with stamp difference 178
# WARNING: seq 3127: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 3753: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2704: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 1990: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3346: consecutive leaving on stage spout and spout with stamp difference 187
# WARNING: seq 2553: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 2171: consecutive leaving on stage spout and spout with stamp difference 142
# WARNING: seq 3606: consecutive leaving on stage spout and spout with stamp difference 175
# WARNING: seq 2813: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3455: consecutive leaving on stage spout and spout with stamp difference 147
# WARNING: seq 2406: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3032: consecutive leaving on stage spout and spout with stamp difference 162
# WARNING: seq 3699: consecutive leaving on stage spout and spout with stamp difference 291
# WARNING: seq 2650: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1664: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 3292: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2243: consecutive leaving on stage spout and spout with stamp difference 90
# WARNING: seq 2885: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3527: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2478: consecutive leaving on stage spout and spout with stamp difference 44
# WARNING: seq 3129: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3771: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2722: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1992: consecutive leaving on stage spout and spout with stamp difference 140
# WARNING: seq 3364: consecutive leaving on stage spout and spout with stamp difference 120
# WARNING: seq 2315: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2957: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 3608: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2575: consecutive leaving on stage spout and spout with stamp difference 230
# WARNING: seq 3201: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2408: consecutive leaving on stage spout and spout with stamp difference 62
# WARNING: seq 3050: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2668: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 1682: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 1682: consecutive leaving on stage scale and scale with stamp difference 107
# WARNING: seq 3310: consecutive leaving on stage spout and spout with stamp difference 48
# WARNING: seq 2261: consecutive leaving on stage spout and spout with stamp difference 48
# WARNING: seq 2903: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 3529: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2480: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 3147: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 3789: consecutive leaving on stage spout and spout with stamp difference 118
# WARNING: seq 2740: consecutive leaving on stage spout and spout with stamp difference 131
# WARNING: seq 2010: consecutive leaving on stage spout and spout with stamp difference 107
# WARNING: seq 3382: consecutive leaving on stage spout and spout with stamp difference 155
# WARNING: seq 1628: consecutive leaving on stage spout and spout with stamp difference 170
# WARNING: seq 2333: consecutive leaving on stage spout and spout with stamp difference 110
# WARNING: seq 2975: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3626: consecutive leaving on stage spout and spout with stamp difference 162
# WARNING: seq 2577: consecutive leaving on stage spout and spout with stamp difference 134
# WARNING: seq 1863: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 3219: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2426: consecutive leaving on stage spout and spout with stamp difference 130
# WARNING: seq 3068: consecutive leaving on stage spout and spout with stamp difference 103
# WARNING: seq 2686: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1700: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 3312: consecutive leaving on stage spout and spout with stamp difference 170
# WARNING: seq 2279: consecutive leaving on stage spout and spout with stamp difference 65
# WARNING: seq 2905: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 1935: consecutive leaving on stage spout and spout with stamp difference 98
# WARNING: seq 3547: consecutive leaving on stage spout and spout with stamp difference 249
# WARNING: seq 2498: consecutive leaving on stage spout and spout with stamp difference 168
# WARNING: seq 3165: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2116: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3807: consecutive leaving on stage spout and spout with stamp difference 137
# WARNING: seq 2758: consecutive leaving on stage spout and spout with stamp difference 150
# WARNING: seq 2028: consecutive leaving on stage spout and spout with stamp difference 149
# WARNING: seq 3384: consecutive leaving on stage spout and spout with stamp difference 91
# WARNING: seq 1646: consecutive leaving on stage spout and spout with stamp difference 108
# WARNING: seq 2351: consecutive leaving on stage spout and spout with stamp difference 145
# WARNING: seq 2977: consecutive leaving on stage spout and spout with stamp difference 79
# WARNING: seq 3644: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 2595: consecutive leaving on stage spout and spout with stamp difference 153
# WARNING: seq 1865: consecutive leaving on stage spout and spout with stamp difference 107
# WARNING: seq 3237: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 2188: consecutive leaving on stage spout and spout with stamp difference 154
# WARNING: seq 2830: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3456: consecutive leaving on stage spout and spout with stamp difference 58
# WARNING: seq 1718: consecutive leaving on stage spout and spout with stamp difference 60
# WARNING: seq 1718: consecutive leaving on stage scale and scale with stamp difference 75
# WARNING: seq 3074: consecutive leaving on stage spout and spout with stamp difference 162
# WARNING: seq 2281: consecutive leaving on stage spout and spout with stamp difference 153
# WARNING: seq 3716: consecutive leaving on stage spout and spout with stamp difference 88
# WARNING: seq 2923: consecutive leaving on stage spout and spout with stamp difference 127
# WARNING: seq 1937: consecutive leaving on stage spout and spout with stamp difference 51
# WARNING: seq 3565: consecutive leaving on stage spout and spout with stamp difference 48
# WARNING: seq 2516: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 3183: consecutive leaving on stage spout and spout with stamp difference 177
# WARNING: seq 2134: consecutive leaving on stage spout and spout with stamp difference 102
# WARNING: seq 3809: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2760: consecutive leaving on stage spout and spout with stamp difference 94
# WARNING: seq 2046: consecutive leaving on stage spout and spout with stamp difference 59
# WARNING: seq 3402: consecutive leaving on stage spout and spout with stamp difference 475
# WARNING: seq 1648: consecutive leaving on stage spout and spout with stamp difference 56
# WARNING: seq 2353: consecutive leaving on stage spout and spout with stamp difference 121
# WARNING: seq 2995: consecutive leaving on stage spout and spout with stamp difference 98
# WARNING: seq 3662: consecutive leaving on stage spout and spout with stamp difference 155
# WARNING: seq 2613: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 1883: consecutive leaving on stage spout and spout with stamp difference 69
# WARNING: seq 3255: consecutive leaving on stage spout and spout with stamp difference 133
# WARNING: seq 2206: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2832: consecutive leaving on stage spout and spout with stamp difference 118
# WARNING: seq 3474: consecutive leaving on stage spout and spout with stamp difference 96
# WARNING: seq 1720: consecutive leaving on stage spout and spout with stamp difference 143
# WARNING: seq 1720: consecutive leaving on stage scale and scale with stamp difference 85
# WARNING: seq 3092: consecutive leaving on stage spout and spout with stamp difference 314
# WARNING: seq 2299: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3734: consecutive leaving on stage spout and spout with stamp difference 175
# WARNING: seq 2941: consecutive leaving on stage spout and spout with stamp difference 50
# WARNING: seq 1955: consecutive leaving on stage spout and spout with stamp difference 129
# WARNING: seq 3583: consecutive leaving on stage spout and spout with stamp difference 97
# WARNING: seq 2534: consecutive leaving on stage spout and spout with stamp difference 68
# WARNING: seq 3185: consecutive leaving on stage spout and spout with stamp difference 131
# WARNING: seq 2136: consecutive leaving on stage spout and spout with stamp difference 121
# WARNING: seq 2778: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3420: consecutive leaving on stage spout and spout with stamp difference 114
# WARNING: seq 2371: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3013: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3664: consecutive leaving on stage spout and spout with stamp difference 93
# WARNING: seq 2631: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 1901: consecutive leaving on stage spout and spout with stamp difference 108
# WARNING: seq 3257: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 2208: consecutive leaving on stage spout and spout with stamp difference 68
# WARNING: seq 2850: consecutive leaving on stage spout and spout with stamp difference 150
# WARNING: seq 3492: consecutive leaving on stage spout and spout with stamp difference 48
# WARNING: seq 2443: consecutive leaving on stage spout and spout with stamp difference 136
# WARNING: seq 3110: consecutive leaving on stage spout and spout with stamp difference 95
# WARNING: seq 2061: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 3736: consecutive leaving on stage spout and spout with stamp difference 84
# WARNING: seq 2703: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1973: consecutive leaving on stage spout and spout with stamp difference 42
# WARNING: seq 3329: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 2536: consecutive leaving on stage spout and spout with stamp difference 181
# WARNING: seq 2154: consecutive leaving on stage spout and spout with stamp difference 159
# WARNING: seq 3589: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 2796: consecutive leaving on stage spout and spout with stamp difference 169
# WARNING: seq 3438: consecutive leaving on stage spout and spout with stamp difference 129
# WARNING: seq 2389: consecutive leaving on stage spout and spout with stamp difference 86
# WARNING: seq 3031: consecutive leaving on stage spout and spout with stamp difference 110
# WARNING: seq 3682: consecutive leaving on stage spout and spout with stamp difference 126
# WARNING: seq 2633: consecutive leaving on stage spout and spout with stamp difference 45
# WARNING: seq 1919: consecutive leaving on stage spout and spout with stamp difference 128
# WARNING: seq 3275: consecutive leaving on stage spout and spout with stamp difference 119
# WARNING: seq 2226: consecutive leaving on stage spout and spout with stamp difference 114
# WARNING: seq 2868: consecutive leaving on stage spout and spout with stamp difference 174
# WARNING: seq 3510: consecutive leaving on stage spout and spout with stamp difference 85
# WARNING: seq 2461: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 3112: consecutive leaving on stage spout and spout with stamp difference 101
# WARNING: seq 3754: consecutive leaving on stage spout and spout with stamp difference 60
# WARNING: seq 2705: consecutive leaving on stage spout and spout with stamp difference 43
# WARNING: seq 1991: consecutive leaving on stage spout and spout with stamp difference 98
# WARNING: seq 3347: consecutive leaving on stage spout and spout with stamp difference 43
# Auto fixed cross stage timming issues for 2091 log entries
# Dropped 2044 frames
# 1144 frames left the final stage but still marked failed

# %%
gpu.seq_latency()

# %%
gpu.latency()

# %%
gpu.fps([('Leaving','scale')])

# %%
ilb.reload(ana)
gpu2 = ana.exp_res('2016-7-07/4')

# %%
gpu2.seq_latency()

# %%
gpu2.latency(range(1000, 4000))

# %%
gpu2.fps([('Leaving', 'fat_features')])
